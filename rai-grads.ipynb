# %%
import torch as th
import numpy as np

from matplotlib import pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes
from collections.abc import Callable
from typing import Any, cast
from torch.nn import Parameter, Module, MSELoss
from torch import Tensor, nn
from sklearn.datasets import make_moons
from tqdm import tqdm
from numpy import ndarray
from torchviz import make_dot

# %%
class RAI(Module):
    _func: Module # The function/module to call
    _loss_fn: Module # Loss function to compute the intermeldiate loss

    def __init__(self, func: Module, loss: Module = MSELoss()) -> None:
        super().__init__()
        self._func = func
        self._loss_fn = loss
    
    def forward(self, *arg: Any, **kwg: Any) -> th.Tensor:
        pred = cast(Callable[..., th.Tensor], self._func)
        if self.training:
            if not hasattr(self, "cache"):
                self.cache = Parameter(pred(*arg, **kwg).detach())
            self.loss = self._loss_fn(self.cache, pred(*arg, **kwg))
            return self.cache
        return pred(*arg, **kwg)

# %%
class LossFn(Module):
    _func: Module # The function/module to call
    _loss_fn: Module # Loss function to compute the output head's loss

    def __init__(self, func: Module, loss: Module = MSELoss()) -> None:
        super().__init__()
        self._func = func
        self._loss_fn = loss

    def forward(self, y: Tensor, *arg: Any, **kwg: Any) -> th.Tensor:
        pred = cast(Callable[..., th.Tensor], self._func)
        loss = self._loss_fn(pred(*arg, **kwg), y)
        for m in self.modules():
            if hasattr(m, "loss"):
                loss = loss + m.loss
        return loss

# %%
def fit(func: Module, optcls: type[th.optim.Optimizer], x: Tensor, y: Tensor, num_itr: int, show: bool = True, **kws: Any) -> tuple[float, ...]:
    func.train(True)
    try:
        func(y, x)
        optim = optcls(func.parameters(), **kws)
        for _ in (bar := tqdm(range(num_itr), unit="itr", disable=not show)):
            optim.zero_grad()
            (loss := func(y, x)).backward()
            optim.step()
            bar.set_description(f"L{loss.item():.4f}")
    finally:
        func.train(False)

# %%
x, y = cast(tuple[ndarray[Any, Any], ...], make_moons(n_samples=100, noise=0.1, random_state=42))
x = th.tensor(x, dtype=th.float32)
y = th.tensor(y, dtype=th.float32).unsqueeze(1)
x[:5], y[:5]
# Out:
# (tensor([[ 1.5820, -0.4458],
#          [ 0.0660,  0.4392],
#          [ 0.7366, -0.3990],
#          [-1.0569,  0.2425],
#          [-0.8022,  0.2027]]),
#  tensor([[1.],
#          [1.],
#          [1.],
#          [0.],
#          [0.]]))

# %%
def landscape(func: Callable[[float, float], float], 
              low: tuple[float, float] = (-1.0, -1.0),
              high: tuple[float, float] = (+1.0, +1.0),
              resolution: int = 100,
              cmap: str = 'viridis',
              alpha: float = 0.7,
              title: str = 'Function Lascape',
              data: tuple[Any, Any] | None = None,
              figsize: tuple[int, int] = (10, 8),
              show: bool = True) -> tuple[Figure, Axes]:
    x_range = (low[0], high[0])
    y_range = (low[1], high[1])

    fig, ax = plt.subplots(figsize=figsize)
    
    x_min, x_max = x_range
    y_min, y_max = y_range
    x_grid = np.linspace(x_min, x_max, resolution)
    y_grid = np.linspace(y_min, y_max, resolution)
    XX, YY = np.meshgrid(x_grid, y_grid)
    
    ZZ = np.zeros_like(XX)
    for i in range(resolution):
        for j in range(resolution):
            ZZ[i, j] = func(XX[i, j], YY[i, j])
    
    im = ax.pcolormesh(XX, YY, ZZ, cmap=cmap, alpha=alpha, shading='auto')
    
    cbar = plt.colorbar(im, ax=ax)
    cbar.set_label('Function Value')
    
    if data is not None:
        X, y = data
        if isinstance(X, th.Tensor):
            X = X.detach().cpu().numpy()
        if isinstance(y, th.Tensor):
            y = y.detach().cpu().numpy()
        
        if y.ndim > 1 and y.shape[1] == 1:
            y = y.squeeze()
            
        scatter = ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, 
                           edgecolors='k', s=80, alpha=0.8)
        
        if len(np.unique(y)) <= 10:
            ax.legend(*scatter.legend_elements(), title="Classes")
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title(title)
    
    plt.tight_layout()
    
    if show:
        plt.show()
    
    return fig, ax

# %%
class MLP(Module):
    mlp: Module

    def __init__(self, widths: list[int]):
        super().__init__()
        assert 2 < len(widths), f"Need at least input and output dimensions; got {widths}"
        self.mlp = nn.Sequential()
        for i in range(len(widths) - 1):
            self.mlp.append(nn.Linear(widths[i], widths[i + 1]))
            if i < len(widths) - 2:
                self.mlp.append(nn.Sigmoid())
        self.mlp.append(nn.Sigmoid())
    
    def forward(self, x: Tensor) -> Tensor:
        return self.mlp(x)

# %%
mlp = MLP([2, *([100] * 100), 1])
mlp
# Out:
# MLP(
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=100, out_features=100, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=100, out_features=100, bias=True)
#     (7): Sigmoid()
#     (8): Linear(in_features=100, out_features=100, bias=True)
#     (9): Sigmoid()
#     (10): Linear(in_features=100, out_features=100, bias=True)
#     (11): Sigmoid()
#     (12): Linear(in_features=100, out_features=100, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=100, out_features=100, bias=True)
#     (15): Sigmoid()
#     (16): Linear(in_features=100, out_features=100, bias=True)
#     (17): Sigmoid()
#     (18): Linear(in_features=100, out_features=100, bias=True)
#     (19): Sigmoid()
#     (20): Linear(in_features=100, out_features=100, bias=True)
#     (21): Sigmoid()
#     (22): Linear(in_features=100, out_features=100, bias=True)
#     (23): Sigmoid()
#     (24): Linear(in_features=100, out_features=100, bias=True)
#     (25): Sigmoid()
#     (26): Linear(in_features=100, out_features=100, bias=True)
#     (27): Sigmoid()
#     (28): Linear(in_features=100, out_features=100, bias=True)
#     (29): Sigmoid()
#     (30): Linear(in_features=100, out_features=100, bias=True)
#     (31): Sigmoid()
#     (32): Linear(in_features=100, out_features=100, bias=True)
#     (33): Sigmoid()
#     (34): Linear(in_features=100, out_features=100, bias=True)
#     (35): Sigmoid()
#     (36): Linear(in_features=100, out_features=100, bias=True)
#     (37): Sigmoid()
#     (38): Linear(in_features=100, out_features=100, bias=True)
#     (39): Sigmoid()
#     (40): Linear(in_features=100, out_features=100, bias=True)
#     (41): Sigmoid()
#     (42): Linear(in_features=100, out_features=100, bias=True)
#     (43): Sigmoid()
#     (44): Linear(in_features=100, out_features=100, bias=True)
#     (45): Sigmoid()
#     (46): Linear(in_features=100, out_features=100, bias=True)
#     (47): Sigmoid()
#     (48): Linear(in_features=100, out_features=100, bias=True)
#     (49): Sigmoid()
#     (50): Linear(in_features=100, out_features=100, bias=True)
#     (51): Sigmoid()
#     (52): Linear(in_features=100, out_features=100, bias=True)
#     (53): Sigmoid()
#     (54): Linear(in_features=100, out_features=100, bias=True)
#     (55): Sigmoid()
#     (56): Linear(in_features=100, out_features=100, bias=True)
#     (57): Sigmoid()
#     (58): Linear(in_features=100, out_features=100, bias=True)
#     (59): Sigmoid()
#     (60): Linear(in_features=100, out_features=100, bias=True)
#     (61): Sigmoid()
#     (62): Linear(in_features=100, out_features=100, bias=True)
#     (63): Sigmoid()
#     (64): Linear(in_features=100, out_features=100, bias=True)
#     (65): Sigmoid()
#     (66): Linear(in_features=100, out_features=100, bias=True)
#     (67): Sigmoid()
#     (68): Linear(in_features=100, out_features=100, bias=True)
#     (69): Sigmoid()
#     (70): Linear(in_features=100, out_features=100, bias=True)
#     (71): Sigmoid()
#     (72): Linear(in_features=100, out_features=100, bias=True)
#     (73): Sigmoid()
#     (74): Linear(in_features=100, out_features=100, bias=True)
#     (75): Sigmoid()
#     (76): Linear(in_features=100, out_features=100, bias=True)
#     (77): Sigmoid()
#     (78): Linear(in_features=100, out_features=100, bias=True)
#     (79): Sigmoid()
#     (80): Linear(in_features=100, out_features=100, bias=True)
#     (81): Sigmoid()
#     (82): Linear(in_features=100, out_features=100, bias=True)
#     (83): Sigmoid()
#     (84): Linear(in_features=100, out_features=100, bias=True)
#     (85): Sigmoid()
#     (86): Linear(in_features=100, out_features=100, bias=True)
#     (87): Sigmoid()
#     (88): Linear(in_features=100, out_features=100, bias=True)
#     (89): Sigmoid()
#     (90): Linear(in_features=100, out_features=100, bias=True)
#     (91): Sigmoid()
#     (92): Linear(in_features=100, out_features=100, bias=True)
#     (93): Sigmoid()
#     (94): Linear(in_features=100, out_features=100, bias=True)
#     (95): Sigmoid()
#     (96): Linear(in_features=100, out_features=100, bias=True)
#     (97): Sigmoid()
#     (98): Linear(in_features=100, out_features=100, bias=True)
#     (99): Sigmoid()
#     (100): Linear(in_features=100, out_features=100, bias=True)
#     (101): Sigmoid()
#     (102): Linear(in_features=100, out_features=100, bias=True)
#     (103): Sigmoid()
#     (104): Linear(in_features=100, out_features=100, bias=True)
#     (105): Sigmoid()
#     (106): Linear(in_features=100, out_features=100, bias=True)
#     (107): Sigmoid()
#     (108): Linear(in_features=100, out_features=100, bias=True)
#     (109): Sigmoid()
#     (110): Linear(in_features=100, out_features=100, bias=True)
#     (111): Sigmoid()
#     (112): Linear(in_features=100, out_features=100, bias=True)
#     (113): Sigmoid()
#     (114): Linear(in_features=100, out_features=100, bias=True)
#     (115): Sigmoid()
#     (116): Linear(in_features=100, out_features=100, bias=True)
#     (117): Sigmoid()
#     (118): Linear(in_features=100, out_features=100, bias=True)
#     (119): Sigmoid()
#     (120): Linear(in_features=100, out_features=100, bias=True)
#     (121): Sigmoid()
#     (122): Linear(in_features=100, out_features=100, bias=True)
#     (123): Sigmoid()
#     (124): Linear(in_features=100, out_features=100, bias=True)
#     (125): Sigmoid()
#     (126): Linear(in_features=100, out_features=100, bias=True)
#     (127): Sigmoid()
#     (128): Linear(in_features=100, out_features=100, bias=True)
#     (129): Sigmoid()
#     (130): Linear(in_features=100, out_features=100, bias=True)
#     (131): Sigmoid()
#     (132): Linear(in_features=100, out_features=100, bias=True)
#     (133): Sigmoid()
#     (134): Linear(in_features=100, out_features=100, bias=True)
#     (135): Sigmoid()
#     (136): Linear(in_features=100, out_features=100, bias=True)
#     (137): Sigmoid()
#     (138): Linear(in_features=100, out_features=100, bias=True)
#     (139): Sigmoid()
#     (140): Linear(in_features=100, out_features=100, bias=True)
#     (141): Sigmoid()
#     (142): Linear(in_features=100, out_features=100, bias=True)
#     (143): Sigmoid()
#     (144): Linear(in_features=100, out_features=100, bias=True)
#     (145): Sigmoid()
#     (146): Linear(in_features=100, out_features=100, bias=True)
#     (147): Sigmoid()
#     (148): Linear(in_features=100, out_features=100, bias=True)
#     (149): Sigmoid()
#     (150): Linear(in_features=100, out_features=100, bias=True)
#     (151): Sigmoid()
#     (152): Linear(in_features=100, out_features=100, bias=True)
#     (153): Sigmoid()
#     (154): Linear(in_features=100, out_features=100, bias=True)
#     (155): Sigmoid()
#     (156): Linear(in_features=100, out_features=100, bias=True)
#     (157): Sigmoid()
#     (158): Linear(in_features=100, out_features=100, bias=True)
#     (159): Sigmoid()
#     (160): Linear(in_features=100, out_features=100, bias=True)
#     (161): Sigmoid()
#     (162): Linear(in_features=100, out_features=100, bias=True)
#     (163): Sigmoid()
#     (164): Linear(in_features=100, out_features=100, bias=True)
#     (165): Sigmoid()
#     (166): Linear(in_features=100, out_features=100, bias=True)
#     (167): Sigmoid()
#     (168): Linear(in_features=100, out_features=100, bias=True)
#     (169): Sigmoid()
#     (170): Linear(in_features=100, out_features=100, bias=True)
#     (171): Sigmoid()
#     (172): Linear(in_features=100, out_features=100, bias=True)
#     (173): Sigmoid()
#     (174): Linear(in_features=100, out_features=100, bias=True)
#     (175): Sigmoid()
#     (176): Linear(in_features=100, out_features=100, bias=True)
#     (177): Sigmoid()
#     (178): Linear(in_features=100, out_features=100, bias=True)
#     (179): Sigmoid()
#     (180): Linear(in_features=100, out_features=100, bias=True)
#     (181): Sigmoid()
#     (182): Linear(in_features=100, out_features=100, bias=True)
#     (183): Sigmoid()
#     (184): Linear(in_features=100, out_features=100, bias=True)
#     (185): Sigmoid()
#     (186): Linear(in_features=100, out_features=100, bias=True)
#     (187): Sigmoid()
#     (188): Linear(in_features=100, out_features=100, bias=True)
#     (189): Sigmoid()
#     (190): Linear(in_features=100, out_features=100, bias=True)
#     (191): Sigmoid()
#     (192): Linear(in_features=100, out_features=100, bias=True)
#     (193): Sigmoid()
#     (194): Linear(in_features=100, out_features=100, bias=True)
#     (195): Sigmoid()
#     (196): Linear(in_features=100, out_features=100, bias=True)
#     (197): Sigmoid()
#     (198): Linear(in_features=100, out_features=100, bias=True)
#     (199): Sigmoid()
#     (200): Linear(in_features=100, out_features=1, bias=True)
#     (201): Sigmoid()
#   )
# )

# %%
fit(LossFn(mlp, nn.BCELoss()), th.optim.Rprop, cast(Tensor, x), cast(Tensor, y), num_itr=10000, lr=0.1)
# Out:
# L0.6931: 100%|██████████| 10000/10000 [13:37<00:00, 12.23itr/s]

# %%
def fn_mlp(x: float, y: float) -> float:
    """Function to evaluate the MLP classifier."""
    with th.no_grad():
        return mlp(th.tensor([[x, y]], dtype=th.float32)).item()

landscape(fn_mlp, low=(-3., -3.), high=(3., 3.), resolution=100, cmap='viridis', alpha=0.7, title='MLP Classifier Landscape', data=(x, y));

# %%
class RAI_MLP(Module):
    mlp: Module

    def __init__(self, widths: list[int]):
        super().__init__()
        assert 2 < len(widths), f"Need at least input and output dimensions; got {widths}"
        self.mlp = nn.Sequential()
        for i in range(len(widths) - 1):
            self.mlp.append(RAI(nn.Linear(widths[i], widths[i + 1])))
            if i < len(widths) - 2:
                self.mlp.append(nn.Sigmoid())
        self.mlp.append(nn.Sigmoid())
    
    def forward(self, x: Tensor) -> Tensor:
        return self.mlp(x)

# %%
rai_mlp = RAI_MLP([2, *([100] * 100), 1])
rai_mlp
# Out:
# RAI_MLP(
#   (mlp): Sequential(
#     (0): RAI(
#       (_func): Linear(in_features=2, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (1): Sigmoid()
#     (2): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (3): Sigmoid()
#     (4): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (5): Sigmoid()
#     (6): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (7): Sigmoid()
#     (8): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (9): Sigmoid()
#     (10): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (11): Sigmoid()
#     (12): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (13): Sigmoid()
#     (14): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (15): Sigmoid()
#     (16): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (17): Sigmoid()
#     (18): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (19): Sigmoid()
#     (20): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (21): Sigmoid()
#     (22): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (23): Sigmoid()
#     (24): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (25): Sigmoid()
#     (26): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (27): Sigmoid()
#     (28): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (29): Sigmoid()
#     (30): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (31): Sigmoid()
#     (32): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (33): Sigmoid()
#     (34): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (35): Sigmoid()
#     (36): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (37): Sigmoid()
#     (38): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (39): Sigmoid()
#     (40): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (41): Sigmoid()
#     (42): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (43): Sigmoid()
#     (44): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (45): Sigmoid()
#     (46): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (47): Sigmoid()
#     (48): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (49): Sigmoid()
#     (50): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (51): Sigmoid()
#     (52): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (53): Sigmoid()
#     (54): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (55): Sigmoid()
#     (56): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (57): Sigmoid()
#     (58): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (59): Sigmoid()
#     (60): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (61): Sigmoid()
#     (62): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (63): Sigmoid()
#     (64): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (65): Sigmoid()
#     (66): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (67): Sigmoid()
#     (68): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (69): Sigmoid()
#     (70): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (71): Sigmoid()
#     (72): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (73): Sigmoid()
#     (74): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (75): Sigmoid()
#     (76): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (77): Sigmoid()
#     (78): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (79): Sigmoid()
#     (80): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (81): Sigmoid()
#     (82): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (83): Sigmoid()
#     (84): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (85): Sigmoid()
#     (86): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (87): Sigmoid()
#     (88): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (89): Sigmoid()
#     (90): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (91): Sigmoid()
#     (92): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (93): Sigmoid()
#     (94): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (95): Sigmoid()
#     (96): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (97): Sigmoid()
#     (98): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (99): Sigmoid()
#     (100): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (101): Sigmoid()
#     (102): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (103): Sigmoid()
#     (104): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (105): Sigmoid()
#     (106): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (107): Sigmoid()
#     (108): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (109): Sigmoid()
#     (110): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (111): Sigmoid()
#     (112): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (113): Sigmoid()
#     (114): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (115): Sigmoid()
#     (116): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (117): Sigmoid()
#     (118): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (119): Sigmoid()
#     (120): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (121): Sigmoid()
#     (122): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (123): Sigmoid()
#     (124): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (125): Sigmoid()
#     (126): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (127): Sigmoid()
#     (128): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (129): Sigmoid()
#     (130): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (131): Sigmoid()
#     (132): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (133): Sigmoid()
#     (134): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (135): Sigmoid()
#     (136): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (137): Sigmoid()
#     (138): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (139): Sigmoid()
#     (140): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (141): Sigmoid()
#     (142): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (143): Sigmoid()
#     (144): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (145): Sigmoid()
#     (146): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (147): Sigmoid()
#     (148): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (149): Sigmoid()
#     (150): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (151): Sigmoid()
#     (152): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (153): Sigmoid()
#     (154): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (155): Sigmoid()
#     (156): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (157): Sigmoid()
#     (158): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (159): Sigmoid()
#     (160): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (161): Sigmoid()
#     (162): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (163): Sigmoid()
#     (164): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (165): Sigmoid()
#     (166): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (167): Sigmoid()
#     (168): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (169): Sigmoid()
#     (170): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (171): Sigmoid()
#     (172): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (173): Sigmoid()
#     (174): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (175): Sigmoid()
#     (176): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (177): Sigmoid()
#     (178): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (179): Sigmoid()
#     (180): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (181): Sigmoid()
#     (182): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (183): Sigmoid()
#     (184): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (185): Sigmoid()
#     (186): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (187): Sigmoid()
#     (188): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (189): Sigmoid()
#     (190): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (191): Sigmoid()
#     (192): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (193): Sigmoid()
#     (194): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (195): Sigmoid()
#     (196): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (197): Sigmoid()
#     (198): RAI(
#       (_func): Linear(in_features=100, out_features=100, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (199): Sigmoid()
#     (200): RAI(
#       (_func): Linear(in_features=100, out_features=1, bias=True)
#       (_loss_fn): MSELoss()
#     )
#     (201): Sigmoid()
#   )
# )

# %%
fit(LossFn(rai_mlp, nn.BCELoss()), th.optim.Rprop, cast(Tensor, x), cast(Tensor, y), num_itr=10000, lr=0.1)
# Out:
# L0.0002: 100%|██████████| 10000/10000 [22:26<00:00,  7.43itr/s]

# %%
def fn_emlp(x: float, y: float) -> float:
    """Function to evaluate the MLP classifier."""
    with th.no_grad():
        return rai_mlp(th.tensor([[x, y]], dtype=th.float32)).item()

landscape(fn_emlp, low=(-3., -3.), high=(3., 3.), resolution=100, cmap='viridis', alpha=0.7, title='RAI MLP Classifier Landscape', data=(x, y));
